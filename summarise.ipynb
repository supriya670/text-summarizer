# %%
pip install sumy
# Out:
# Requirement already satisfied: sumy in c:\users\supri\onedrive\desktop\summarize\myvenv\lib\site-packages (0.11.0)
# Requirement already satisfied: docopt<0.7,>=0.6.1 in c:\users\supri\onedrive\desktop\summarize\myvenv\lib\site-packages (from sumy) (0.6.2)
# Requirement already satisfied: breadability>=0.1.20 in c:\users\supri\onedrive\desktop\summarize\myvenv\lib\site-packages (from sumy) (0.1.20)
# Requirement already satisfied: requests>=2.7.0 in c:\users\supri\onedrive\desktop\summarize\myvenv\lib\site-packages (from sumy) (2.32.3)
# Requirement already satisfied: pycountry>=18.2.23 in c:\users\supri\onedrive\desktop\summarize\myvenv\lib\site-packages (from sumy) (24.6.1)
# Requirement already satisfied: nltk>=3.0.2 in c:\users\supri\onedrive\desktop\summarize\myvenv\lib\site-packages (from sumy) (3.8.1)
# Requirement already satisfied: chardet in c:\users\supri\onedrive\desktop\summarize\myvenv\lib\site-packages (from breadability>=0.1.20->sumy) (5.2.0)
# Requirement already satisfied: lxml>=2.0 in c:\users\supri\onedrive\desktop\summarize\myvenv\lib\site-packages (from breadability>=0.1.20->sumy) (5.2.2)
# Requirement already satisfied: click in c:\users\supri\onedrive\desktop\summarize\myvenv\lib\site-packages (from nltk>=3.0.2->sumy) (8.1.7)
# Requirement already satisfied: joblib in c:\users\supri\onedrive\desktop\summarize\myvenv\lib\site-packages (from nltk>=3.0.2->sumy) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\supri\onedrive\desktop\summarize\myvenv\lib\site-packages (from nltk>=3.0.2->sumy) (2024.5.15)
# Requirement already satisfied: tqdm in c:\users\supri\onedrive\desktop\summarize\myvenv\lib\site-packages (from nltk>=3.0.2->sumy) (4.66.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\supri\onedrive\desktop\summarize\myvenv\lib\site-packages (from requests>=2.7.0->sumy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\supri\onedrive\desktop\summarize\myvenv\lib\site-packages (from requests>=2.7.0->sumy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\supri\onedrive\desktop\summarize\myvenv\lib\site-packages (from requests>=2.7.0->sumy) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\supri\onedrive\desktop\summarize\myvenv\lib\site-packages (from requests>=2.7.0->sumy) (2024.7.4)
# Requirement already satisfied: colorama in c:\users\supri\onedrive\desktop\summarize\myvenv\lib\site-packages (from click->nltk>=3.0.2->sumy) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import sumy
# Out:
# 0.11.0

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\supri\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# Import necessary libraries
from sumy.parsers.plaintext import PlaintextParser
from sumy.nlp.tokenizers import Tokenizer
from sumy.summarizers.text_rank import TextRankSummarizer

text = """Initial text content"""
# Multi-line text data
text = text

# Create a PlaintextParser object with your text data
parser = PlaintextParser.from_string(text, Tokenizer("english"))

# Initialize the TextRankSummarizer
summarizer = TextRankSummarizer()

# Summarize the document; '2' is the number of sentences in the summary
summary = summarizer(parser.document, 2)

# Concatenate the summary sentences into a single string
text_summary = ""
for sentence in summary:
    text_summary += str(sentence) + " "

# Print the summarized text
print(text_summary)
# Out:
# Her sixth concert tour, the Eras Tour (2023–present), and its accompanying concert film are respectively the highest-grossing tour and concert film of all time; Swift became the first billionaire with music as the main source of income, and the highest-grossing female touring act. Her accolades include 14 Grammy Awards, a Primetime Emmy Award, 40 American Music Awards, 39 Billboard Music Awards, and 23 MTV Video Music Awards; she has won the Grammy Award for Album of the Year, the MTV Video Music Award for Video of the Year, and the IFPI Global Recording Artist of the Year a record four times each.
